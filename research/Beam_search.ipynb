# %%
import os
import subprocess
import torch
import re
import pickle
import time
os.chdir('../')

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy

from IPython.display import HTML as html_print
from research.utils import load_vocabulary, Tokenizer, Aligner, RelaxedTargetField, OneHotEncoder, bleu
from research.scorer import Scorer
from research.greedy_optimizer import GreedyOptimizer
from research.beam_optimizer import BeamOptimizer
from research.continuous_optimizer import ContinuousOptimizer
from research.exponentiated_gradient_optimizer import ExponentiatedGradientOptimizer

# %%
vocab = load_vocabulary()
tokenizer = Tokenizer()

# %%
WMT_DIR = '/home/pma/wmt/'
german_path = WMT_DIR + 'test.de'
english_path = WMT_DIR + 'test.en'

def cstr(s, color='black'):
    return "<text style=color:{}>{}</text>".format(color, s)

def load_test_data(path):
    with open(path) as f:
        return [tokenizer.detokenize(line.split()) for line in f.readlines()]

def load_reference_data(path):
    with open(path) as f:
        return [line.strip() for line in f.readlines()]

class BeamTestResult(object):
    
    def __init__(self, translations, scores, bleus):
        self.translations = translations
        self.scores = scores
        self.bleus = bleus
    
    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self, f, pickle.HIGHEST_PROTOCOL)
            
    
def beam_test(k=50, beamsize=15, temperature=1.):
    scorer = Scorer(temperature=temperature)
    english_sentences = load_test_data(english_path)
    references = load_reference_data(german_path)    
    i = 0
    bleus = []
    scores = []
    translations = []
    times = []
    bleu_score = 0.
    for english_sentence, reference in zip(english_sentences[:k], references):
        i += 1
        print('Sentence', i)
        print(english_sentence)
        english_tok = tokenizer.tokenize(english_sentence)
        optimizer = BeamOptimizer(english_sentence, beamsize, temperature=temperature)
        
        start_ts = time.time()
        tmp = optimizer.optimize()
        translation = tmp[0][0][:-1]
        end_ts = time.time()
        time_elapsed = end_ts - start_ts
        
        print(' '.join(translation))
        score = -scorer.score_tokenized_texts([english_tok], [translation], relaxed=False, normalize=True).item()
        obleu = bleu(reference, ' '.join(translation))
        print('dscore = ', score)
        print('bleu = ', obleu)
        print('time elapsed = ', time_elapsed, 's')
        print()
        
        bleu_score += obleu
        bleus += [obleu]
        scores += [score]
        translations += [translation]
        times += [time_elapsed]
        
    print('Beam size = ', beamsize, 'avg bleu = ', float(bleu_score) / k)
    res = BeamTestResult(translations, scores, bleus)
    res.save(f'beam_test_{k}_{beamsize}.pkl')
    return res

# %% [markdown]
# ### Beam size = 1

# %%
beam_test(k=100, beamsize=1)
# Out:
# Sentence 1
# 28-Year-Old Chef Found Dead at San Francisco Mall
# ▁28 - Jahr - O ld ▁Chef ▁Found ▁Dead
# dscore =  0.5151540637016296
# bleu =  0.0
# time elapsed =  0.5672750473022461 s
#
# Sentence 2
# A 28-year-old chef who had recently moved to San Francisco was found dead in the stairwell of a local mall this week.
# ▁Ein ▁28 - jährige r ▁Küchen chef , ▁der ▁kürz lich ▁nach ▁San ▁Francisco ▁ zog , ▁wurde ▁diese ▁Woche ▁im ▁Trepp en haus ▁einer ▁lokale n ▁Mal l ▁to t ▁auf gefunden .
# dscore =  0.49215784668922424
# bleu =  31.29
# time elapsed =  2.7126717567443848 s
#
# Sentence 3
# But the victim's brother says he can't think of anyone who would want to hurt him, saying, "Things were finally going well for him."
# ▁Aber ▁der ▁Bruder ▁des ▁Opfer s ▁sagt , ▁er ▁könne ▁niemand en ▁denken , ▁der ▁ihn ▁verletz en ▁würde , ▁und ▁sagt : ▁" Es ▁ging ▁ihm ▁endlich ▁gut . "
# dscore =  0.5355032086372375
# bleu =  11.46
# time elapsed =  2.7048144340515137 s
#
# Sentence 4
# The body found at the Westfield Mall Wednesday morning was identified as 28-year-old San Francisco resident Frank Galicia, the San Francisco Medical Examiner's Office said.
# ▁Die ▁Körper ▁in ▁der ▁West field ▁Mal l ▁Mittwoch ▁Morgen ▁wurde ▁als ▁28 - jährige r ▁in ▁San ▁Francisco ▁Wohn sitz ▁Frank ▁Galicia ▁identifi ziert , ▁sagte ▁der ▁San ▁Francisco ▁Medical ▁Ex ami ner ' s ▁Office .
# dscore =  0.418877512216568
# bleu =  20.01
# time elapsed =  3.523012161254883 s
#
# Sentence 5
# The San Francisco Police Department said the death was ruled a homicide and an investigation is ongoing.
# ▁Die ▁Polizei abteilung ▁von ▁San ▁Francisco ▁sagte , ▁dass ▁der ▁Tod ▁eines ▁Mord es ▁be urteil t ▁wurde ▁und ▁eine ▁Untersuchung ▁an hält .
# dscore =  0.7827282547950745
# bleu =  20.29
# time elapsed =  1.701446771621704 s
#
# Sentence 6
# The victim's brother, Louis Galicia, told ABC station KGO in San Francisco that Frank, previously a line cook in Boston, had landed his dream job as line chef at San Francisco's Sons & Daughters restaurant six months ago.
# ▁Der ▁Bruder ▁des ▁Opfer s , ▁Louis ▁Galicia , ▁sagte ▁der ▁A BC - Station ▁K GO ▁in ▁San ▁Francisco , ▁dass ▁Frank , ▁der ▁zuvor ▁in ▁Boston ▁als ▁Linien koch ▁tätig ▁war , ▁vor ▁sechs ▁Monaten ▁seinen ▁Traum job ▁als ▁Küchen chef ▁im ▁Restaurant ▁Son s ▁& ▁D aught ers ▁in ▁San ▁Francisco ▁ge land et ▁hatte .
# dscore =  0.47621670365333557
# bleu =  48.5
# time elapsed =  7.060247421264648 s
#
# Sentence 7
# A spokesperson for Sons & Daughters said they were "shocked and devastated" by his death.
# ▁Ein ▁Sprech er ▁für ▁Söhne ▁und ▁Tö chter ▁sagte , ▁dass ▁sie ▁durch ▁seinen ▁Tod ▁" ver spot tet ▁und ▁verw üstet " ▁seien .
# dscore =  0.4737871289253235
# bleu =  17.15
# time elapsed =  1.9229872226715088 s
#
# Sentence 8
# "We are a small team that operates like a close knit family and he will be dearly missed," the spokesperson said.
# ▁" Wir ▁sind ▁ein ▁kleines ▁Team , ▁das ▁wie ▁eine ▁enge ▁k n it ▁Familie ▁arbeitet ▁und ▁er ▁wird ▁sehr ▁vermiss t ▁werden ", ▁sagte ▁der ▁Sprech er .
# dscore =  0.4113239645957947
# bleu =  48.83
# time elapsed =  2.584150791168213 s
#
# Sentence 9
# Our thoughts and condolences are with Frank's family and friends at this difficult time.
# ▁Unsere ▁Gedanken ▁und ▁unser ▁Bei leid ▁sind ▁bei ▁Frank s ▁Familie ▁und ▁Freunden ▁in ▁dieser ▁schwierig en ▁Zeit .
# dscore =  0.5129178166389465
# bleu =  65.99
# time elapsed =  2.3993356227874756 s
#
# Sentence 10
# Louis Galicia said Frank initially stayed in hostels, but recently, "Things were finally going well for him."
# ▁Louis ▁Galicia ▁sagte ▁Frank ▁zu nächst ▁in ▁den ▁Herberge n , ▁aber ▁vor ▁kurze m : ▁„ Die ▁Dinge ▁ klapp ten ▁ihm ▁endlich ▁gut . "
# dscore =  0.7988974452018738
# bleu =  12.5
# time elapsed =  2.1285624504089355 s
#
# Sentence 11
# "He found an apartment, he was dating a girl," Louis Galicia told KGO.
# ▁" Er ▁fand ▁eine ▁Wohnung , ▁er ▁war ▁ein ▁Mädchen , " ▁Louis ▁Gal izi en ▁sagte ▁K GO .
# dscore =  0.5281389355659485
# bleu =  34.0
# time elapsed =  1.3870444297790527 s
#
# Sentence 12
# Louis Galicia said he could not think of anyone who would want to hurt his younger brother.
# ▁Louis ▁Galicia ▁sagte , ▁er ▁könne ▁niemand en ▁denken , ▁der ▁seinen ▁jüng er en ▁Bruder ▁verletz en ▁möchte .
# dscore =  0.45707157254219055
# bleu =  26.73
# time elapsed =  2.459350109100342 s
#
# Sentence 13
# He was a kind spirit with a big heart.
# ▁Er ▁war ▁ein ▁freundlich er ▁Geist ▁mit ▁einem ▁großen ▁Herz .
# dscore =  0.40280836820602417
# bleu =  52.54
# time elapsed =  0.6932580471038818 s
#
# Sentence 14
# His way of connecting with the family was always making us a dish, making us dinner," Louis Galicia said.
# ▁Seine ▁Verbindung ▁mit ▁der ▁Familie ▁machte ▁uns ▁immer ▁zu ▁einem ▁Gericht , ▁das ▁uns ▁zum ▁Abendessen ▁machte ", ▁sagte ▁Louis ▁Galici en .
# dscore =  0.520112931728363
# bleu =  0.0
# time elapsed =  1.6854097843170166 s
#
# Sentence 15
# He never wanted to be in any kind of altercation.
# ▁Er ▁wollte ▁nie ▁in ▁irgendeine r ▁Weise ▁in ▁irgendeine r ▁Weise ▁von ▁Veränderungen ▁sein .
# dscore =  1.0596872568130493
# bleu =  0.0
# time elapsed =  0.9414005279541016 s
#
# Sentence 16
# He was the brother that went with the flow.
# ▁Er ▁war ▁der ▁Bruder , ▁der ▁mit ▁dem ▁Fluss ▁ging .
# dscore =  0.3537465035915375
# bleu =  61.32
# time elapsed =  0.6393582820892334 s
#
# Sentence 17
# "With everything else that's going wrong with the world, he was that diamond in the rough that was shining bright every day," he said.
# ▁" Mit ▁allem , ▁was ▁mit ▁der ▁Welt ▁schief ▁läuft , ▁war ▁er ▁der ▁Diamant ▁in ▁der ▁rau en , ▁die ▁jeden ▁Tag ▁ strahl end ▁schien ", ▁sagte ▁er .
# dscore =  0.5464362502098083
# bleu =  28.31
# time elapsed =  2.7715985774993896 s
#
# Sentence 18
# Anyone with information is asked to call the SFPD Tip Line at 415-575-4444.
# ▁Jeder , ▁der ▁Informationen ▁hat , ▁wird ▁gebe ten , ▁die ▁S F PD - T ipp - Linie ▁unter ▁4 15 -5 75 - 44 44 ▁anzu rufen .
# dscore =  0.529942512512207
# bleu =  49.06
# time elapsed =  2.2255537509918213 s
#
# Sentence 19
# Jennifer Aniston: I'm always pigeonholed
# ▁J en ni fer ▁An ist on : ▁Ich ▁bin ▁immer ▁mit ▁P ig e on en ▁gef ütter t .
# dscore =  0.8773913383483887
# bleu =  41.01
# time elapsed =  1.4006292819976807 s
#
# Sentence 20
# Jennifer Aniston need not always be perfect or successful.
# ▁J en ni fer ▁An ist on ▁muss ▁nicht ▁immer ▁perfekt ▁oder ▁erfolgreich ▁sein .
# dscore =  0.1678551286458969
# bleu =  100.0
# time elapsed =  0.9414002895355225 s
#
# Sentence 21
# That is what the Hollywood star has made abundantly clear in an interview.
# ▁Das ▁hat ▁der ▁Hollywood - Star ▁in ▁einem ▁Interview ▁mehr ▁als ▁deutlich ▁gemacht .
# dscore =  0.3610643446445465
# bleu =  61.15
# time elapsed =  0.883021354675293 s
#
# Sentence 22
# "I'm always pigeonholed, or labelled by someone who has little, if anything, to do with me and reality."
# ▁" Ich ▁bin ▁immer ▁mit ▁einem ▁P ig ment ▁be kleide t ▁oder ▁von ▁jemand em ▁gekennzeichnet , ▁der , ▁wenn ▁überhaupt , ▁wenig ▁mit ▁mir ▁und ▁der ▁Realität ▁zu ▁tun ▁hat . ▁"
# dscore =  0.7506160736083984
# bleu =  15.06
# time elapsed =  2.783751964569092 s
#
# Sentence 23
# "Personally, I have no desire to be perfect and successful all the time."
# ▁" Per s ö n lich ▁habe ▁ich ▁keine n ▁Wunsch , ▁immer ▁perfekt ▁und ▁erfolgreich ▁zu ▁sein . ▁"
# dscore =  0.48416948318481445
# bleu =  41.53
# time elapsed =  1.313460350036621 s
#
# Sentence 24
# "To be honest, I don't really give a damn about things like that."
# ▁" Um ▁ehrlich ▁zu ▁sein , ▁gebe ▁ich ▁keine n ▁wirklich en ▁Ver damm nis ▁über ▁solche ▁Dinge . "
# dscore =  0.5508469343185425
# bleu =  0.0
# time elapsed =  1.38997220993042 s
#
# Sentence 25
# Jennifer Aniston (47) can only laugh that she has been dubbed "Miss Perfect" in the current issue of "Cosmopolitan".
# ▁J en ni fer ▁An ist on ▁( 47 ) ▁kann ▁nur ▁la chen , ▁dass ▁sie ▁in ▁der ▁aktuelle n ▁Ausgabe ▁von ▁" K osmopolit an " ▁als ▁" Mi s s ▁Perfect " ▁bezeichnet ▁wurde .
# dscore =  0.23542645573616028
# bleu =  63.61
# time elapsed =  3.4893572330474854 s
#
# Sentence 26
# The actress prefers to spend her time at home in front of the television with her hair in a relaxed bun, eating Mexican food, the magazine reports.
# ▁Die ▁Schauspieler in ▁ zieht ▁es ▁vor , ▁ihre ▁Zeit ▁zu ▁Hause ▁vor ▁dem ▁Fernsehen ▁mit ▁ihre m ▁Haar ▁in ▁einem ▁entspannt en ▁Bu n ▁zu ▁verbringen , ▁essen ▁mex ikanische ▁Lebensmittel , ▁berichtet ▁die ▁Zeitschrift .
# dscore =  0.5059648752212524
# bleu =  0.0
# time elapsed =  3.1731925010681152 s
#
# Sentence 27
# The question of whether she wants children makes her livid: "We women do not need to be married or have children to feel fulfilled," the Hollywood star says.
# ▁Die ▁Frage , ▁ob ▁sie ▁Kinder ▁haben ▁möchte , ▁ist ▁ihre ▁Lü ge : ▁" Wir ▁Frauen ▁brauchen ▁nicht ▁verhe irate t ▁zu ▁werden ▁oder ▁Kinder ▁zu ▁haben , ▁um ▁sich ▁erfüllt ▁zu ▁fühl en ", ▁sagt ▁der ▁Hollywood - Star .
# dscore =  0.6018204689025879
# bleu =  22.27
# time elapsed =  3.826101303100586 s
#
# Sentence 28
# In her new film, "Mother's Day - love isn't child's play", Aniston stars as a single mother with two sons.
# ▁In ▁ihre m ▁neue n ▁Film ▁" M other ' s ▁Day ▁- ▁love ▁is n ' t ▁child ' s ▁play " ▁ schlägt ▁An ist on ▁als ▁eine ▁allein er ziehen de ▁Mutter ▁mit ▁zwei ▁Söhne n .
# dscore =  0.39282190799713135
# bleu =  54.6
# time elapsed =  3.7147116661071777 s
#
# Sentence 29
# The film is released in Germany on 25 August.
# ▁Der ▁Film ▁wird ▁am ▁25. ▁August ▁in ▁Deutschland ▁veröffentlicht .
# dscore =  0.3767436146736145
# bleu =  0.0
# time elapsed =  0.5834112167358398 s
#
# Sentence 30
# Golfer Langer is awarded the Sport Pyramid
# ▁Golf er ▁Lang er ▁wird ▁mit ▁der ▁Sport ▁Py ram ide ▁ausgezeichnet .
# dscore =  0.4223611056804657
# bleu =  23.8
# time elapsed =  0.7687113285064697 s
#
# Sentence 31
# His experience on horseback is negligible.
# ▁Seine ▁Erfahrung en ▁auf ▁dem ▁Pferd ▁sind ▁vernachlässig bar .
# dscore =  0.5811247825622559
# bleu =  66.06
# time elapsed =  0.5787980556488037 s
#
# Sentence 32
# At the end of a golfing tournament in South Africa, Bernhard Langer and a colleague went for a ride along the beach for a bit of fun.
# ▁Am ▁Ende ▁eines ▁Golf t urnier s ▁in ▁Südafrika ▁ fuhr en ▁Bernhard ▁Lang er ▁und ▁ein ▁Kolleg e ▁für ▁ein ▁wenig ▁Spaß ▁am ▁Strand ▁entlang .
# dscore =  0.3473149836063385
# bleu =  37.03
# time elapsed =  2.231954336166382 s
#
# Sentence 33
# It was a first for the 58-year-old.
# ▁Es ▁war ▁ein ▁erst er ▁für ▁den ▁58 - jährige n .
# dscore =  0.5009310841560364
# bleu =  0.0
# time elapsed =  0.7589130401611328 s
#
# Sentence 34
# CHIO: "Golden Sport Pyramid" for Bernhard Langer
# ▁CH IO : ▁" G old en e ▁Sport py ram ide ▁für ▁Bernhard ▁Lang er "
# dscore =  0.27801209688186646
# bleu =  76.25
# time elapsed =  1.1409263610839844 s
#
# Sentence 35
# After a few minutes, the horse decided it wanted to go home, and raced back to its feeding trough at full tilt.
# ▁Nach ▁ein ▁paar ▁Minuten ▁entschied ▁das ▁Pferd , ▁es ▁wollte ▁nach ▁Hause ▁gehen , ▁und ▁ fuhr ▁zurück ▁zu ▁seine m ▁Futter tro g ▁bei ▁volle m ▁Til t .
# dscore =  0.590915322303772
# bleu =  0.0
# time elapsed =  2.4043755531311035 s
#
# Sentence 36
# After a kilometre at this speed I was scared.
# ▁Nach ▁einem ▁Kilometer ▁mit ▁dieser ▁Geschwindigkeit ▁war ▁ich ▁Angst .
# dscore =  0.4189392626285553
# bleu =  0.0
# time elapsed =  1.4463319778442383 s
#
# Sentence 37
# "It wasn't a good experience," said Langer.
# ▁" Es ▁war ▁keine ▁gute ▁Erfahrung ", ▁sagte ▁Lang er .
# dscore =  0.2565825283527374
# bleu =  0.0
# time elapsed =  0.69736647605896 s
#
# Sentence 38
# And with that, his riding career came to an end again.
# ▁Und ▁damit ▁ist ▁seine ▁Karriere ▁im ▁Reit sport ▁wieder ▁zu ▁Ende ▁gegangen .
# dscore =  0.7693734765052795
# bleu =  0.0
# time elapsed =  0.8039023876190186 s
#
# Sentence 39
# On Saturday, Germany's best golfer of all time - with 101 tournament wins under his belt - was once again near horses.
# ▁Am ▁Samstag ▁war ▁Deutschlands ▁best er ▁Golf er ▁aller ▁Zeiten ▁- ▁mit ▁101 ▁Turnier sieg en ▁unter ▁seine m ▁G ürt el ▁- ▁wieder ▁einmal ▁bei ▁Pferde n .
# dscore =  0.3647630214691162
# bleu =  44.65
# time elapsed =  3.0829036235809326 s
#
# Sentence 40
# He and his family toured the ALRV grounds, but he did not jump onto a horse for a photo.
# ▁Er ▁und ▁seine ▁Familie ▁re isten ▁auf ▁dem ▁A LR V - Park , ▁aber ▁er ▁ griff ▁nicht ▁auf ▁ein ▁Pferd ▁für ▁ein ▁Foto .
# dscore =  0.6902999877929688
# bleu =  0.0
# time elapsed =  2.0508980751037598 s
#
# Sentence 41
# It was Langer's first time in Aachen, and at CHIO.
# ▁Es ▁war ▁das ▁erste ▁Mal ▁Lang er ▁in ▁Aachen ▁und ▁bei ▁CH IO .
# dscore =  0.3892704248428345
# bleu =  31.31
# time elapsed =  0.9100198745727539 s
#
# Sentence 42
# He had been thoroughly convinced.
# ▁Er ▁war ▁ gründlich ▁überzeugt .
# dscore =  0.5035057067871094
# bleu =  0.0
# time elapsed =  0.34693002700805664 s
#
# Sentence 43
# The German Sport Aid foundation awarded the man from Anhausen with the Golden Sport Pyramid at a small gala event.
# ▁Die ▁Deutsche ▁Sport ▁Aid ▁Stiftung ▁verlie h ▁dem ▁An haus er ▁bei ▁einer ▁kleinen ▁Gala ▁den ▁Golden en ▁Sport ▁Py ram ide .
# dscore =  0.5638771653175354
# bleu =  0.0
# time elapsed =  1.761173963546753 s
#
# Sentence 44
# The friendly sportsman is not lacking for awards.
# ▁Der ▁freundliche ▁Sportler ▁fehlt ▁nicht ▁für ▁Auszeichnung en .
# dscore =  0.5723285675048828
# bleu =  0.0
# time elapsed =  0.5248620510101318 s
#
# Sentence 45
# The Federal Cross of Merit, the Silver Laurel Leaf, Champions Tour Player of the Year...
# ▁Das ▁Bundes ver dienst kreuz , ▁das ▁Silber blatt , ▁Champion s ▁Tour ▁Player ▁of ▁the ▁Year ...
# dscore =  0.44105836749076843
# bleu =  29.27
# time elapsed =  1.2657709121704102 s
#
# Sentence 46
# Even the British Queen has bestowed an honour upon him.
# ▁Selbst ▁die ▁britische ▁König in ▁hat ▁ihm ▁eine ▁Ehre ▁zu teil ▁werden ▁lassen .
# dscore =  0.3046220541000366
# bleu =  0.0
# time elapsed =  0.9047458171844482 s
#
# Sentence 47
# Langer is the 18th person to be awarded the Sport Pyramid.
# ▁Lang er ▁ist ▁die ▁18 te ▁Person , ▁die ▁mit ▁der ▁Sport ▁Py ram ide ▁ausgezeichnet ▁wurde .
# dscore =  0.48935335874557495
# bleu =  0.0
# time elapsed =  1.205364465713501 s
#
# Sentence 48
# On Saturday, he met the first person to receive it, Hans Günter Winkler, in Aachen.
# ▁Am ▁Samstag ▁traf ▁er ▁in ▁Aachen ▁den ▁ersten ▁Menschen , ▁der ▁ihn ▁empfangen ▁hat , ▁Hans ▁G ü n ter ▁W inkl er .
# dscore =  0.45253661274909973
# bleu =  36.08
# time elapsed =  1.7565808296203613 s
#
# Sentence 49
# "This award means a lot to me," said Langer, "because it's not just given for sporting success, but also for social commitment."
# ▁" Diese ▁Auszeichnung ▁bedeutet ▁für ▁mich ▁viel ", ▁sagte ▁Lang er , ▁" da ▁sie ▁nicht ▁nur ▁für ▁sportliche n ▁Erfolg , ▁sonder n ▁auch ▁für ▁soziale s ▁Engagement ▁vergeben ▁wird . "
# dscore =  0.3733322024345398
# bleu =  35.84
# time elapsed =  3.7431154251098633 s
#
# Sentence 50
# Langer has been encouraging up-and-coming talent for years.
# ▁Lang er ▁ fördert ▁seit ▁Jahren ▁auf streb ende ▁Talent e .
# dscore =  0.36047592759132385
# bleu =  0.0
# time elapsed =  0.751880407333374 s
#
# Sentence 51
# And in this vein, he passed the prize money of 25,000 euros on straight away.
# ▁Und ▁in ▁diesem ▁Sinne ▁hat ▁er ▁sofort ▁das ▁Preis geld ▁von ▁2 5.000 ▁Euro ▁über wiesen .
# dscore =  0.47843530774116516
# bleu =  39.92
# time elapsed =  1.2348132133483887 s
#
# Sentence 52
# The two-time US master's champion was inaugurated into the "Hall of Fame for German Sport" on Saturday, along with 15 other outstanding sportspeople.
# ▁Der ▁zwei malig e ▁US - Me ist er meister ▁wurde ▁am ▁Samstag ▁zusammen ▁mit ▁15 ▁weiteren ▁herausragend en ▁Sportler n ▁in ▁das ▁" H all ▁of ▁Fa me ▁for ▁German ▁Sport " ▁einge weih t .
# dscore =  0.41291525959968567
# bleu =  30.36
# time elapsed =  3.409698009490967 s
#
# Sentence 53
# Those given the award include track athletes Hartwig Gauder and Harald Schmitt, gymnast Eberhard Gienger, fencers Cornelia Hanisch, Alexander Putsch and Arnd Schmitt, rower Peter-Michael Kolbe, bob-sleigh rider Meinhard Nehmer, judo player Frank Wieneke, show-jumper Alwin Schockemöhle, and, posthumously, handball player Erhard Wunderlich.
# ▁Zu ▁den ▁Preis trägern ▁gehören ▁die ▁Renn sport ler ▁Hart wig ▁Gau der ▁und ▁Har al d ▁Schmitt , ▁Gy m na s tik erin ▁E ber hard ▁Gi en ger , ▁Za un meister ▁Corn e lia ▁Han isch , ▁Alexander ▁Put sch ▁und ▁Arn d ▁Schmitt , ▁Ru der er ▁Peter - Mi cha el ▁Kol be , ▁Bo b - S le igh - Fahr er ▁Mein hard ▁Ne hm er , ▁Ju do spieler ▁Frank ▁Wien e ke , ▁Show - Ju mp er ▁Al win ▁Schock e mö hl e ▁und ▁Hand ball spieler ▁Er h .
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-da46518b2be4> in <module>()
# ----> 1 beam_test(k=100, beamsize=1)
#
# <ipython-input-3-bef8cb4018a9> in beam_test(k, beamsize, temperature)
#      51         print(' '.join(translation))
#      52         score = -scorer.score_tokenized_texts([english_tok], [translation], relaxed=False, normalize=True).item()
# ---> 53         obleu = bleu(reference, ' '.join(translation))
#      54         print('dscore = ', score)
#      55         print('bleu = ', obleu)
#
# ~/Dropbox/Documents/Studia/Semestr_7/Praca_Inzynierska/OpenNMT-py/research/utils.py in bleu(translation, reference)
#      25         f.write(reference)
#      26
# ---> 27     process = subprocess.Popen(['perl', BLEU_SCRIPT_PATH, 'tmp.de'], stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#      28     process.stdin.write(translation.encode('utf-8'))
#      29     process.stdin.close()
#
# ~/anaconda3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ~/anaconda3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1273                             errread, errwrite,
#    1274                             errpipe_read, errpipe_write,
# -> 1275                             restore_signals, start_new_session, preexec_fn)
#    1276                     self._child_created = True
#    1277                 finally:
#
# OSError: [Errno 12] Cannot allocate memory
